# %% [markdown]
# # PROJECT1: GROUP 5
# - As a team member, I was allocated to clean and explore the Region_Income data.
# - I looked at the component of the changes of GDP and Co2 Emissions in different regions over time.

# %% [markdown]
# ### Reading Regions csv file and opening to understand the content

# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import CSV file
## I was getting a UnicodeDecodeError:'utf-8', and used 'encoding="ISO-8859-1' to solve the error
Region_income = pd.read_csv("Region_Income.csv",encoding="ISO-8859-1")

# %%
Region_income.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  Fiscal year end: March 20; reporting period fo...
# 3  22 countries, stretching from the westernmost ...
# 4                                                NaN
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
Region_income
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
#Rename column
Region_income.rename(columns={'TableName': 'CountryName'}, inplace=True)

# %%
#check
Region_income.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  Fiscal year end: March 20; reporting period fo...
# 3  22 countries, stretching from the westernmost ...
# 4                                                NaN
#
#                    CountryName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
#Drop a column
#I dropped the column 'special notes' and 'Country Code' since I dont think we need the information 
#Region_income.drop('SpecialNotes', axis =1, inplace =True)
columns= ['SpecialNotes', 'Country Code']
Region_income.drop(columns, inplace =True, axis =1)

# %%
#check
Region_income.head()
# Out:
#                       Region          IncomeGroup                  CountryName
# 0  Latin America & Caribbean          High income                        Aruba
# 1                        NaN                  NaN  Africa Eastern and Southern
# 2                 South Asia           Low income                  Afghanistan
# 3                        NaN                  NaN   Africa Western and Central
# 4         Sub-Saharan Africa  Lower middle income                       Angola

# %%
##Remove countries with NAN  
Region_income.dropna(inplace = True)

# %%
##Change the order of the data frame
Region_income = Region_income.reindex(['CountryName', 'Region','IncomeGroup'], axis =1)

# %%
Region_income.head()
# Out:
#    CountryName                     Region          IncomeGroup
# 0        Aruba  Latin America & Caribbean          High income
# 2  Afghanistan                 South Asia           Low income
# 4       Angola         Sub-Saharan Africa  Lower middle income
# 5      Albania      Europe & Central Asia  Upper middle income
# 6      Andorra      Europe & Central Asia          High income

# %%
Region_income.rename(columns = {'CountryName':'Country'}, inplace = True)

# %%
Region_income.head()
# Out:
#        Country                     Region          IncomeGroup
# 0        Aruba  Latin America & Caribbean          High income
# 2  Afghanistan                 South Asia           Low income
# 4       Angola         Sub-Saharan Africa  Lower middle income
# 5      Albania      Europe & Central Asia  Upper middle income
# 6      Andorra      Europe & Central Asia          High income

# %%
Region_income.to_csv('Cleaner_Region_Income_data.csv')

# %%
Region_df = pd.read_csv("Cleaner_Region_income_data.csv",encoding="ISO-8859-1")

# %%
Region_df.head()
# Out:
#    Unnamed: 0      Country                     Region          IncomeGroup
# 0           0        Aruba  Latin America & Caribbean          High income
# 1           2  Afghanistan                 South Asia           Low income
# 2           4       Angola         Sub-Saharan Africa  Lower middle income
# 3           5      Albania      Europe & Central Asia  Upper middle income
# 4           6      Andorra      Europe & Central Asia          High income

# %% [markdown]
# ## Reading GDP csv file cleaned by another team member

# %%
GDP_df = pd.read_csv("clean_gdp.csv",encoding="ISO-8859-1")

# %%
GDP_df.head()
# Out:
#    Unnamed: 0                      Country Country Code          1990  \
# 0           1  Africa Eastern and Southern          AFE  2.121860e+11
# 1           3   Africa Western and Central          AFW  1.218020e+11
# 2           5                      Albania          ALB  2.028554e+09
# 3           7                   Arab World          ARB  6.225470e+11
# 4           8         United Arab Emirates          ARE  5.070144e+10
#
#            1991          1992          1993          1994          1995  \
# 0  2.206080e+11  2.200630e+11  2.338700e+11  2.389190e+11  2.694990e+11
# 1  1.174570e+11  1.182820e+11  9.882641e+10  8.628177e+10  1.082210e+11
# 2  1.099559e+09  6.521750e+08  1.185315e+09  1.880952e+09  2.392765e+09
# 3  4.386820e+11  4.737120e+11  4.826630e+11  5.076600e+11  5.559390e+11
# 4  5.155217e+10  5.423917e+10  5.562517e+10  5.930509e+10  6.574367e+10
#
#            1996  ...          2011          2012          2013          2014  \
# ...

# %% [markdown]
# ## Merge the two dataframes (Region and GDP DF) using an inner join

# %%
## Merge two dataframes (Region and GDP DF) using an inner join
merged_df = pd.merge(Region_df, GDP_df, on="Country")
merged_df.head()
# Out:
#    Unnamed: 0_x               Country                      Region  \
# 0             5               Albania       Europe & Central Asia
# 1             8  United Arab Emirates  Middle East & North Africa
# 2             9             Argentina   Latin America & Caribbean
# 3            10               Armenia       Europe & Central Asia
# 4            12   Antigua and Barbuda   Latin America & Caribbean
#
#            IncomeGroup  Unnamed: 0_y Country Code          1990          1991  \
# 0  Upper middle income             5          ALB  2.028554e+09  1.099559e+09
# 1          High income             8          ARE  5.070144e+10  5.155217e+10
# 2  Upper middle income             9          ARG  1.413520e+11  1.897200e+11
# 3  Upper middle income            10          ARM  2.256839e+09  2.069870e+09
# 4          High income            12          ATG  4.594704e+08  4.817074e+08
#
#            1992          1993  ...          2011          2012          2013  \
# ...

# %%
#drop irrelevant columns names
merged_df = merged_df.drop(['Country Code', 'Unnamed: 0_x', 'Unnamed: 0_y'], axis = 1)

# %%
merged_df.head()
# Out:
#                 Country                      Region          IncomeGroup  \
# 0               Albania       Europe & Central Asia  Upper middle income
# 1  United Arab Emirates  Middle East & North Africa          High income
# 2             Argentina   Latin America & Caribbean  Upper middle income
# 3               Armenia       Europe & Central Asia  Upper middle income
# 4   Antigua and Barbuda   Latin America & Caribbean          High income
#
#            1990          1991          1992          1993          1994  \
# 0  2.028554e+09  1.099559e+09  6.521750e+08  1.185315e+09  1.880952e+09
# 1  5.070144e+10  5.155217e+10  5.423917e+10  5.562517e+10  5.930509e+10
# 2  1.413520e+11  1.897200e+11  2.287890e+11  2.367420e+11  2.574400e+11
# 3  2.256839e+09  2.069870e+09  1.272835e+09  1.201313e+09  1.315159e+09
# 4  4.594704e+08  4.817074e+08  4.992815e+08  5.351741e+08  5.894296e+08
#
#            1995          1996  ...          2011          2012          2013  \
# ...

# %%
merged_df.to_csv('Merged_GDP-REGION.csv', index=False, sep=',')

# %% [markdown]
# ## Graphic

# %%
import matplotlib.pyplot as plt

# %%
#Import CSV file
gdpregion_df = pd.read_csv("Merged_GDP-REGION.csv")
gdpregion_df.head()
# Out:
#                 Country                      Region          IncomeGroup  \
# 0               Albania       Europe & Central Asia  Upper middle income
# 1  United Arab Emirates  Middle East & North Africa          High income
# 2             Argentina   Latin America & Caribbean  Upper middle income
# 3               Armenia       Europe & Central Asia  Upper middle income
# 4   Antigua and Barbuda   Latin America & Caribbean          High income
#
#            1990          1991          1992          1993          1994  \
# 0  2.028554e+09  1.099559e+09  6.521750e+08  1.185315e+09  1.880952e+09
# 1  5.070144e+10  5.155217e+10  5.423917e+10  5.562517e+10  5.930509e+10
# 2  1.413520e+11  1.897200e+11  2.287890e+11  2.367420e+11  2.574400e+11
# 3  2.256839e+09  2.069870e+09  1.272835e+09  1.201313e+09  1.315159e+09
# 4  4.594704e+08  4.817074e+08  4.992815e+08  5.351741e+08  5.894296e+08
#
#            1995          1996  ...          2011          2012          2013  \
# ...

# %% [markdown]
# ## Reading CO2 Emissions csv file cleaned by another team member

# %%
#Import CSV file
emissionsregion_df = pd.read_csv("ghg-emissions.csv", encoding="ISO-8859-1")

# %%
#remove rows with any NaN values
emissionsregion_df = emissionsregion_df.dropna(how = 'any')
emissionsregion_df
# Out:
#            Country    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1    United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2            India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3           Russia  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4        Indonesia  MtCO2e   1257.1  1274.43  1295.01  1311.27  1327.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188       Kiribati  MtCO2e     0.04     0.04     0.04     0.05     0.04
# 189   Cook Islands  MtCO2e     0.03     0.03     0.03     0.03     0.03
# 190          Nauru  MtCO2e     0.13     0.13     0.13     0.12     0.12
# 191         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# 192           Niue  MtCO2e     0.01     0.01     0.01     0.01     0.01
#
#         1995     1996     1997  ...     2009     2010      2011      2012  \
# ...

# %%
## Merge two dataframes (Region and GDP DF) using an inner join
merged_df = pd.merge(Region_df, emissionsregion_df, on="Country")
merged_df.head()
# Out:
#    Unnamed: 0               Country                      Region  \
# 0           2           Afghanistan                  South Asia
# 1           4                Angola          Sub-Saharan Africa
# 2           5               Albania       Europe & Central Asia
# 3           6               Andorra       Europe & Central Asia
# 4           8  United Arab Emirates  Middle East & North Africa
#
#            IncomeGroup    unit   1990   1991   1992   1993   1994  ...  \
# 0           Low income  MtCO2e  12.79  12.71  11.25  11.08  10.88  ...
# 1  Lower middle income  MtCO2e  65.18  65.85  66.17  66.96  67.10  ...
# 2  Upper middle income  MtCO2e  11.51   9.15   7.09   7.03   7.87  ...
# 3          High income  MtCO2e   0.43   0.43   0.43   0.44   0.44  ...
# 4          High income  MtCO2e  69.71  76.25  74.82  77.76  84.37  ...
#
#      2009    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0   37.08   45.03   58.41   66.50   74.55   84.37   93.48   95.53   97.45
# ...

# %%
#drop irrelevant columns names
clean_emmisionsregion = merged_df.drop(['Unnamed: 0'], axis = 1)

# %%
clean_emmisionsregion.head()
# Out:
#                 Country                      Region          IncomeGroup  \
# 0           Afghanistan                  South Asia           Low income
# 1                Angola          Sub-Saharan Africa  Lower middle income
# 2               Albania       Europe & Central Asia  Upper middle income
# 3               Andorra       Europe & Central Asia          High income
# 4  United Arab Emirates  Middle East & North Africa          High income
#
#      unit   1990   1991   1992   1993   1994   1995  ...    2009    2010  \
# 0  MtCO2e  12.79  12.71  11.25  11.08  10.88  11.09  ...   37.08   45.03
# 1  MtCO2e  65.18  65.85  66.17  66.96  67.10  71.47  ...  128.34  133.35
# 2  MtCO2e  11.51   9.15   7.09   7.03   7.87   7.63  ...    7.73    8.01
# 3  MtCO2e   0.43   0.43   0.43   0.44   0.44   0.46  ...    0.62    0.63
# 4  MtCO2e  69.71  76.25  74.82  77.76  84.37  90.78  ...  202.08  208.58
#
#      2011    2012    2013    2014    2015    2016    2017    2018
# ...

# %%
merged_df.to_csv('Merged_emissions_region.csv',index=False, sep=',')
