# %%
#Dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
fig, ax1 = plt.subplots()

# %%
#Import CSV file
emission = pd.read_csv("..\Data Files\emissions_data_clean.csv", encoding="ISO-8859-1", index_col=0)
gdp_df = pd.read_csv("..\Data Files\Global_US_GDP.csv", skiprows = 4, skipinitialspace=True)

# %%
#drop irrelevant columns names
clean_gdp = gdp_df.drop(['Indicator Name','Indicator Code', 'Unnamed: 65'], axis = 1)

#drop all rows up until 1990 to align with other data emissions data
for x in range(1960,1990):
    clean_gdp = clean_gdp.drop([f'{x}'],axis = 1)

#remove rows with any NaN values
clean_gdp = clean_gdp.dropna(how = 'any')
clean_gdp

#transpose columns
clean_gdp_t = clean_gdp.T
clean_gdp_t.columns = (clean_gdp_t.iloc[0])
clean_gdp_t = clean_gdp_t.drop(clean_gdp_t.index[0])
clean_gdp_t = clean_gdp_t.drop(clean_gdp_t.index[0])

clean_gdp_t.rename(columns={"Country Name" :"Year"})
clean_gdp_t
# Out:
# Country Name Africa Eastern and Southern Africa Western and Central  \
# 1990                 212185847636.195007        121802185300.139008
# 1991                 220607545655.716003        117457042740.623001
# 1992                 220063005938.320007           118282284598.653
# 1993                 233869615673.326996         98826405551.023804
# 1994                 238919172017.812012         86281770253.473999
# 1995                 269498561282.165985        108221322522.552002
# 1996                 268250521535.699005        125763049173.423996
# 1997                 282013878700.820007        127063932192.746994
# 1998                 265649661675.878998        130106844606.852997
# 1999                 262011704777.848999        137520164451.484985
# 2000                 283751640320.984985           140407973778.931
# 2001                 258660109000.795013        148012003011.165985
# 2002                 264707648997.268005        176933365387.395996
# ...

# %%
#emission_clean = emission.drop(['Region','Income Gro



emission_clean = emission.T
emission_clean.rename(columns={"Country/Region" :"Year"})
emission_clean.columns = (emission_clean.iloc[0])
emission_clean = emission_clean.drop(emission_clean.index[0])


emission_clean
#emission_clean = emission_clean.drop(['Palau'], axis = 1)
#emission_clean = emission_clean.astype(float, errors = 'raise')

#flse values in data prevented converting the whole thing to floats...
emission_clean['China'] = emission_clean["China"].astype(float, errors = 'raise')
emission_clean['Japan'] = emission_clean["Japan"].astype(float, errors = 'raise')
emission_clean['Australia'] = emission_clean["Australia"].astype(float, errors = 'raise')
emission_clean['United States'] = emission_clean["United States"].astype(float, errors = 'raise')
emission_clean['India'] = emission_clean["India"].astype(float, errors = 'raise')

emission_clean
# Out:
# Country/Region     China  United States    India   Russia Indonesia   Brazil  \
# 1990             2873.71        5543.47  1009.44  2885.12    1257.1  1642.29
# 1991             3023.38        5501.92  1064.49   2788.7   1274.43  1669.56
# 1992             3154.54        5583.80  1096.71  2551.94   1295.01   1679.5
# 1993             3377.79        5691.26  1128.44  2294.62   1311.27   1689.7
# 1994             3528.81        5782.20  1174.78  2011.47   1327.87  1706.03
# 1995             3918.30        5843.90  1240.44  1930.88   1360.88  1726.08
# 1996             3954.75        6010.62  1289.63  1889.18    1179.0  1735.71
# 1997             3963.61        6258.47  1348.09  1755.59   2142.82  1766.32
# 1998             4103.23        6293.80  1382.26  1740.23   1373.56  1800.62
# 1999             4053.37        6291.25  1460.24  1772.68   1261.56  1810.51
# 2000             4249.70        6446.20  1498.20  1831.09   1191.82  1807.03
# ...

# %%
merged = pd.merge(emission_clean, clean_gdp_t, left_index=True, right_index=True)


merged
# Out:
#        China_x  United States_x  India_x   Russia Indonesia_x Brazil_x  \
# 1990   2873.71          5543.47  1009.44  2885.12      1257.1  1642.29
# 1991   3023.38          5501.92  1064.49   2788.7     1274.43  1669.56
# 1992   3154.54          5583.80  1096.71  2551.94     1295.01   1679.5
# 1993   3377.79          5691.26  1128.44  2294.62     1311.27   1689.7
# 1994   3528.81          5782.20  1174.78  2011.47     1327.87  1706.03
# 1995   3918.30          5843.90  1240.44  1930.88     1360.88  1726.08
# 1996   3954.75          6010.62  1289.63  1889.18      1179.0  1735.71
# 1997   3963.61          6258.47  1348.09  1755.59     2142.82  1766.32
# 1998   4103.23          6293.80  1382.26  1740.23     1373.56  1800.62
# 1999   4053.37          6291.25  1460.24  1772.68     1261.56  1810.51
# 2000   4249.70          6446.20  1498.20  1831.09     1191.82  1807.03
# 2001   4459.91          6406.04  1747.49  1455.44     1019.35  1901.78
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(clean_gdp_t["China"], label= "China")
plt.plot(clean_gdp_t["Japan"], label= "Japan")
plt.plot(clean_gdp_t["Australia"], label= "Australia")
plt.plot(clean_gdp_t["United States"], label= "United States")
plt.plot(clean_gdp_t["India"], label= "India")


plt.title("5x Country GDP Over Time")
plt.legend()
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.xlabel("Year" , fontsize=15)
plt.ylabel("GDP (trillions)", fontsize=15)
gdp_plot = plt.show()
plt.savefig('..\Final Graphs Output\5 Country GDP Snapshot (Doug).png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26704/681896990.py in <module>
#      15 plt.ylabel("GDP (trillions)", fontsize=15)
#      16 gdp_plot = plt.show()
# ---> 17 plt.savefig('..\Final Graphs Output\5 Country GDP Snapshot (Doug).png')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(emission_clean["China"], label= "China")
plt.plot(emission_clean["Japan"], label= "Japan")
plt.plot(emission_clean["Australia"], label= "Australia")
plt.plot(emission_clean["United States"], label= "United States")
plt.plot(emission_clean["India"], label= "India ")


plt.title("5x Country Emissions Over Time")
plt.legend()
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.tick_params(axis='y', which='major', labelsize=15)
plt.xlabel("Year" , fontsize=15)
plt.ylabel("MTCO2e", fontsize=15)
plt.show()
plt.savefig('..\Final Graphs Output\5 Country Emisions Snapshot (Doug).png')

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
plt.title("Emissions(---) vs. GDP by Various Countries", fontsize=20)
color = 'black'
ax1.set_xlabel('Year', fontsize=15)
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.tick_params(axis='y', which='major', labelsize=15)
ax1.set_ylabel('MTCO2e', color=color, fontsize=15)
ax1.plot(emission_clean["China"], label= "China Emissions", color='red', linestyle = "dashed", linewidth=3.0)
ax1.plot(emission_clean["Japan"], label= "Japan Emissions", color = 'blue', linestyle = "dashed", linewidth=3.0)
ax1.plot(emission_clean["Australia"], label= "Australia Emissions", color = 'green', linestyle = "dashed", linewidth=3.0)
ax1.plot(emission_clean["United States"], label= "United States Emissions", color = 'orange', linestyle = "dashed", linewidth=3.0)
ax1.plot(emission_clean["India"], label= "India Emissions ", color = 'purple', linestyle = "dashed", linewidth=3.0)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(loc=9)


ax2 = ax1.twinx()
color = 'black'
ax2.set_ylabel('Trillions ($USD)', color=color, fontsize=15)
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.tick_params(axis='y', which='major', labelsize=15)
ax2.plot(clean_gdp_t["China"], label= "China GDP", color='red', linewidth=3.0)
ax2.plot(clean_gdp_t["Japan"], label= "Japan GDP", color = 'blue', linewidth=3.0)
ax2.plot(clean_gdp_t["Australia"], label= "Australia GDP", color = 'green', linewidth=3.0)
ax2.plot(clean_gdp_t["United States"], label= "United States GDP", color = 'orange', linewidth=3.0)
ax2.plot(clean_gdp_t["India"], label= "India GDP",  color = 'purple' , linewidth=3.0)
ax2.tick_params(axis='y', labelcolor=color)

ax2.legend(loc=2)

fig.tight_layout

plt.savefig("..\Final Graphs Output\Emission vs GDP by Select Countries DOUG.png")
plt.show()
